# %%
import sqlite3
import pandas as pd
import numpy as np
import sys
sys.path.append('C:/Users/Archiebald/Moons/Task_1')
from jupiter import Moons

# %%
sys.path.append('C:/Users/Archiebald/Moons/Task_1')

# %%
jupiter_moons = Moons("jupiter_kepler.db", "data/")

# %%
jupiter_moons.all_data().head()
# Out:
#        moon  period_days  distance_km  radius_km   mag       mass_kg  \
# 0  Adrastea        0.298     129000.0        8.2   NaN           NaN
# 1     Aitne      730.000   23231000.0        1.5  22.7           NaN
# 2  Amalthea        0.498     181400.0       83.5  14.1  2.080000e+18
# 3    Ananke      630.000   21300000.0       14.0  18.9           NaN
# 4     Aoede      761.000   24000000.0        2.0  22.5           NaN
#
#       group       ecc  inclination_deg
# 0     Inner  0.001500             0.03
# 1     Carme  0.264000           165.00
# 2     Inner  0.003190             0.37
# 3    Ananke  0.174725           148.60
# 4  Pasiphae  0.432000           158.00

# %%
jupiter_moons.convert_distance("km", "radius_km")
jupiter_moons.convert_time("days","period_days")
jupiter_moons.gen_sma("semi_major_axis","radius_m","ecc")
jupiter_moons.prepare_data("period_s","semi_major_axis")
# Out:
#        moon  period_days  distance_km  radius_km   mag       mass_kg  \
# 0  Adrastea        0.298     129000.0        8.2   NaN           NaN
# 1     Aitne      730.000   23231000.0        1.5  22.7           NaN
# 2  Amalthea        0.498     181400.0       83.5  14.1  2.080000e+18
# 3    Ananke      630.000   21300000.0       14.0  18.9           NaN
# 4     Aoede      761.000   24000000.0        2.0  22.5           NaN
#
#       group       ecc  inclination_deg  radius_m    period_s  semi_major_axis
# 0     Inner  0.001500             0.03    8200.0     25747.2      8212.318478
# 1     Carme  0.264000           165.00    1500.0  63072000.0      2038.043478
# 2     Inner  0.003190             0.37   83500.0     43027.2     83767.217424
# 3    Ananke  0.174725           148.60   14000.0  54432000.0     16964.038178
# 4  Pasiphae  0.432000           158.00    2000.0  65750400.0      3521.126761

# %%
jupiter_moons.all_data().head()

# %%
jupiter_moons.test_train("T_squared","a_cubed")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 jupiter_moons.test_train("T_squared","a_cubed")
#
# File C:\Users/Archiebald/Moons/Task_1\jupiter.py:214, in Moons.test_train(self, time_column, axis_column)
#     211 x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state = 42)
#     213 self.model = LinearRegression()
# --> 214 self.model.fit(x_train, y_train)
#     216 test_score = self.model.score(x_test, y_test)
#     217 print(f"R-squared value on the test set: {test_score}")
#
# File D:\Documents\Programmes\Anaconda\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
# ...
